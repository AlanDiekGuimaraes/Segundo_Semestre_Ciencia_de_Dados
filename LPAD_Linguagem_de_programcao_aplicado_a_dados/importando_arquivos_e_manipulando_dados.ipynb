# %% [markdown]
# # Importação

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# Importando arquivos locais

# %%
df = pd.read_csv('customers.csv')
print(df.head())
# Out:
#       ID First Name Last Name         Phone   LTV
# 0  4.576     Sophia    Walker  602-310-9331  0,47
# 1  9.488     Evelyn    Harris  171-363-6978  0,36
# 2  7.265      Lucas    Foster  139-658-8905  0,43
# 3  8.555     Elijah     Jones  538-241-9868  0,35
# 4  7.023      Mason    Taylor  937-595-5837  0,31

# %% [markdown]
# Selecione o cliente que tem o maior LTV.

# %%
df.loc[df['LTV']==df['LTV'].max(), ['ID', 'LTV']]
# Out:
#         ID   LTV
# 669  5.707  0,97

# %% [markdown]
# # Manipulação dos dados

# %%
df=pd.DataFrame({'a': [10.1, 10.2, 10.1, 9.8, 9.7, 9.9, 10.2, 10.5, 10.1, 10.3]})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       10 non-null     float64
# dtypes: float64(1)
# memory usage: 212.0 bytes

# %%
df.plot.line()
# Out:
# <Axes: >

# %%
# Alterando a cor para preto
df.plot.line(color='k')
# Out:
# <Axes: >

# %%
# Alterando espessura da linha
df.plot.line(color='k', linewidth=5)
# Out:
# <Axes: >

# %%
# Alterando estilo da linha e mudando a cor.
df.plot.line(color='r', linewidth=5, style= '--')
# Out:
# <Axes: >

# %%
# Adicionando grades no fundo do gráfico. 
df.plot.line(color='r', linewidth=5, style= '--').grid()

# %%
# Histograma
df.plot.hist(bins=5, color='y')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Contar Valores
x=df['a'].value_counts()
print(x)
x.plot.bar(color='b')
# Out:
# a
# 10.1    3
# 10.2    2
# 9.8     1
# 9.7     1
# 9.9     1
# 10.5    1
# 10.3    1
# Name: count, dtype: int64
# <Axes: xlabel='a'>

# %%
x.plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
import seaborn as sns
import numpy as np

x = np.random.randn(100)
y = np.random.randn(100)+2*x
sns.kdeplot(x=x, y=y, cmap = 'hot', shade = True)
# Out:
# C:\Users\84284528572\AppData\Local\Temp\ipykernel_1712\349159858.py:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=x, y=y, cmap = 'hot', shade = True)
# <Axes: >

# %%
# Exemplo com dadosreais
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
setosa = iris.loc[iris.species=='setosa']
virginica = iris.loc[iris.species == 'virginica']

sns.kdeplot(x=setosa.petal_length, y=setosa.petal_width)
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>
